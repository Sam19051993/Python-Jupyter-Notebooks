# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Dropping Columns and Rows in a Dataframe.ipynb',
#  'Indexing and Slicing Dataframes.ipynb',
#  'Loading Files into Pandas DataFrame.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb']

# %%
import pandas as pd
input_data = pd.read_csv("supermarkets.csv",index_col = "ID")

# %%
input_data
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
input_data.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
input_data.columns
# Out:
# Index(['Address', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
input_data.drop("City",1) #Not in-place operation. Hence the city is not dropped from the original dataframe
                            #drop takes in two parameters. One is the column or row that is to be dropped, the other is the axis
                            #If axis = 0 => Row, axis = 1 => Column
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
input_data
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
temp_data = input_data.copy() #temp_data = input_data just creates another name for the data frame. It does not create a separate
                                #dataframe. Thus any changes done to the temp_data will reflect in input_data as well.
temp_data
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
temp_data.drop("City", axis = 1 , inplace = True)

# %%
temp_data
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
input_data.set_index("Address", inplace = True)

# %%
input_data
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
input_data.drop("332 Hill St",0)
# Out:
#                           City       State Country         Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
input_data.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
input_data.drop(input_data.index[2],0)
# Out:
#                           City       State Country         Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
input_data.drop(input_data.columns[0],1)
# Out:
#                             State Country         Name  Employees
# Address
# 3666 21st St             CA 94114     USA      Madeira          8
# 735 Dolores St           CA 94119     USA  Bready Shop         15
# 332 Hill St      California 94114     USA  Super River         25
# 3995 23rd St             CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St        California     USA      Sanchez         12
# 551 Alvarado St          CA 94114     USA   Richvalley         20
